# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\eugene\anaconda3\lib\site-packages (2.26.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\eugene\anaconda3\lib\site-packages (from requests) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\eugene\anaconda3\lib\site-packages (from requests) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\eugene\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\eugene\anaconda3\lib\site-packages (from requests) (3.2)

# %%
import requests
print(requests)
print(requests.get)
# Out:
# <module 'requests' from 'C:\\Users\\eugene\\anaconda3\\lib\\site-packages\\requests\\__init__.py'>
# <function get at 0x000002D23E64F430>

# %%
import requests
url="http://www.daum.net"
print(requests.get(url))

response=requests.get(url)

print(response.text)
# Out:
# <Response [200]>
# <!DOCTYPE html><html lang="ko"> <head> <meta charset="utf-8" /> <title>Daum</title> <meta http-equiv="x-ua-compatible" content="IE=edge" /> <meta property="og:url" content="//www.daum.net/" /> <meta property="og:type" content="website" /> <meta property="og:title" content="Daum" /> <meta http-equiv="Pragma" content="no-cache" /> <meta http-equiv="Expires" content="-1" /> <meta name="referrer" content="origin" /> <meta property="og:image" content="https://i1.daumcdn.net/svc/image/U03/common_icon/5587C4E4012FCD0001" /> <meta property="og:description" content="ëì ê´ì¬ ì½íì¸ ë¥¼ ê°ì¥ ì¦ê²ê² ë³¼ ì ìë Daum" /> <meta name="msapplication-task" content="name=Daum;action-uri=//www.daum.net/;icon-uri=/favicon.ico" /> <meta name="msapplication-task" content="name=ë¯¸ëì´ë¤ì;action-uri=//news.daum.net/;icon-uri=/media_favicon.ico" /> <meta name="msapplication-task" content="name=ë©ì¼;action-uri=//mail.daum.net;icon-uri=/mail_favicon.ico" /> <link href="https://t1.daumcdn.net/top/favicon.ico" rel="shortcut icon" /> <meta name="referrer" content="origin" /> <link rel="search" type="application/opensearchdescription+xml" href="https://search.daum.net/OpenSearch.xml" title="ë¤ì" /> <link rel="stylesheet" href="https://t1.daumcdn.net/top/tiller-pc/h/production/20220420_132344/common.css" /> <script src="https://t1.daumcdn.net/kas/static/na.min.js"></script> <script type="text/javascript"> window.tillerInitData = {"header":{"timestamp":1651392658747},"body":{"tabs":{"media":{"code":"media","name":"ë¯¸ëì´","renderType":"NONE","position":18,"board":false,"morePage":false,"page":"{\"tab\":\"media\",\"page\":1,\"last\":true,\"token\":null,\"ts\":null}"},"katv":{"code":"katv","name":"ì¹´ì¹´ì¤TV","renderType":"NONE","position":19,"board":false,"morePage":false,"page":"{\"tab\":\"katv\",\"page\":1,\"last\":true,\"token\":null,\"ts\":null}"},"social":{"code":"social","name":"ìì","renderType":"NONE","position":20,"board":false,"morePage":false,"page":"{\"tab\":\"social\",\"page\":1,\"last\":true,\"token\":null,\"ts\":null}"},"channel":{"code":"channel","name":"ì±ë","renderType":"NONE","position":21,"board":false,"morePage":false,"page":"{\"tab\":\"channel\",\"page\":1,\"last\":true,\"token\":null,\"ts\":null}"}},"boxes":{"media":[{"code":2372,"type":"PC_MEDIA_NEWS1","items":{"op":{"tab":"news1","title":"ë´ì¤","url":"https://news.daum.net/"},"issue":{"title":"'ì½ë¡ë19' íí©","url":"https://news.daum.net/covid19","iconType":"ISSUE2","status":"on"},"breakingNewsOp":{"minCount":"3","status":"on"},"footLinkLeft":{"foot1":"{\"title\":\"\",\"url\":\"\",\"tiaraTag\":\"\"}","foot0":"{\"title\":\"ì°ì¬\",\"url\":\"https://news.daum.net/series/\",\"tiaraTag\":\"series\"}","foot3":"{\"title\":\"í¬í \",\"url\":\"https://news.daum.net/photo/\",\"tiaraTag\":\"photo\"}","footer":"{\"title\":\"ë´ì¤í\",\"url\":\"https://news.daum.net/\"}","foot2":"{\"title\":\"\",\"url\":\"\",\"tiaraTag\":\"\"}","foot4":"{\"title\":\"í©í¸ì²´í¬\",\"url\":\"https://focus.daum.net/ch/news/factcheck\",\"tiaraTag\":\"factcheck\"}","status":"on"},"footLinkRight":{"foot1":"{\"title\":\"íì¨\",\"url\":\"https://search.daum.net/search?w=tot&q=íì¨&DA=TMZ\",\"tiaraTag\":\"exchange\"}","foot0":"{\"title\":\"ì¦ì\",\"url\":\"https://search.daum.net/search?w=tot&q=ì¦ì&DA=TMZ\",\"tiaraTag\":\"stock\"}","foot3":"{\"title\":\"TVí¸ì±\",\"url\":\"https://search.daum.net/search?w=tot&q=í¸ì±í&DA=TMZ\",\"tiaraTag\":\"tv\"}","foot2":"{\"title\":\"ì´ì¸\",\"url\":\"https://search.daum.net/search?w=tot&q=ì´ì¸&DA=TMZ\",\"tiaraTag\":\"fortune\"}","status":"on"},"specialLink":{"displayType":"specialLink","title":"ì¤ëì KBOë¦¬ê·¸","url":"https://sports.daum.net/schedule/kbo","iconType":"LIVE","status":"on"}},"feeds":{"pc_media_breaking_news":"[]"},"teslas":{"p_news_img_1":[{"id":"hamny-20220501153102011","title":"ë¬, íí´ í´êµ°ê¸°ì§ ê²½ê³ ë³´ì´ì 'ì¤íì´ ëê³ ë' í¬ì ì í©[ì§êµ¬ë¥¼ ë³´ë¤]","label":null,"url":"https://v.d ...
# https://www.daum.net
# b'<!DOCTYPE html><html lang="ko"> <head> <meta charset="utf-8" /> <title>Daum</title> <meta http-equiv="x-ua-compatible" content="IE=edge" /> <meta property="og:url" content="//www.daum.net/" /> <meta property="og:type" content="website" /> <meta property="og:title" content="Daum" /> <meta http-equiv="Pragma" content="no-cache" /> <meta http-equiv="Expires" content="-1" /> <meta name="referrer" content="origin" /> <meta property="og:image" content="https://i1.daumcdn.net/svc/image/U03/common_icon/5587C4E4012FCD0001" /> <meta property="og:description" content="\xeb\x82\x98\xec\x9d\x98 \xea\xb4\x80\xec\x8b\xac \xec\xbd\x98\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xea\xb0\x80\xec\x9e\xa5 \xec\xa6\x90\xea\xb2\x81\xea\xb2\x8c \xeb\xb3\xbc \xec\x88\x98 \xec\x9e\x88\xeb\x8a\x94 Daum" /> <meta name="msapplication-task" content="name=Daum;action-uri=//www.daum.net/;icon-uri=/favicon.ico" /> <meta name="msapplication-task" content="name=\xeb\xaf\xb8\xeb\x94\x94\xec\x96\xb4\xeb\x8b\xa4\xec\x9d\x8c;action-uri=//news.daum.net/;icon-uri=/media_favicon.ico" /> <meta name="msapplication-task" content="name=\xeb\xa9\x94\xec\x9d\xbc;action-uri=//mail.daum.net;icon-uri=/mail_favicon.ico" /> <link href="https://t1.daumcdn.net/top/favicon.ico" rel="shortcut icon" /> <meta name="referrer" content="origin" /> <link rel="search" type="application/opensearchdescription+xml" href="https://search.daum.net/OpenSearch.xml" title="\xeb\x8b\xa4\xec\x9d\x8c" /> <link rel="stylesheet" href="https://t1.daumcdn.net/top/tiller-pc/h/production/20220420_132344/common.css" /> <script src="https://t1.daumcdn.net/kas/static/na.min.js"></script> <script type="text/javascript"> window.tillerInitData = {"header":{"timestamp":1651392658747},"body":{"tabs":{"media":{"code":"media","name":"\xeb\xaf\xb8\xeb\x94\x94\xec\x96\xb4","renderType":"NONE","position":18,"board":false,"morePage":false,"page":"{\\"tab\\":\\"media\\",\\"page\\":1,\\"last\\":true,\\"token\\":null,\\"ts\\":null}"},"katv":{"code":"katv","name":"\xec\xb9\xb4\xec\xb9\xb4\xec\x98\xa4TV","renderType":"NONE","position":19,"board":false,"morePage":false,"page":"{\\"tab\\":\\"katv\\",\\"page\\":1,\\"last\\":true,\\"token\\":null,\\"ts\\":null}"},"social":{"code":"social","name":"\xec\x86\x8c\xec\x85\x9c","renderType":"NONE","position":20,"board":false,"morePage":false,"page":"{\\"tab\\":\\"social\\",\\"page\\":1,\\"last\\":true,\\"token\\":null,\\"ts\\":null}"},"channel":{"code":"channel","name":"\xec\xb1\x84\xeb\x84\x90","renderType":"NONE","position":21,"board":false,"morePage":false,"page":"{\\"tab\\":\\"channel\\",\\"page\\":1,\\"last\\":true,\\"token\\":null,\\"ts\\":null}"}},"boxes":{"media":[{"code":2372,"type":"PC_MEDIA_NEWS1","items":{"op":{"tab":"news1","title":"\xeb\x89\xb4\xec\x8a\xa4","url":"https://news.daum.net/"},"issue":{"title":"\'\xec\xbd\x94\xeb\xa1\x9c\xeb\x82\x9819\' \xed\x98\x84\xed\x99\xa9","url":"https://news.daum.net/covid19","iconType":"ISSUE2","status":"on"},"breakingNewsOp":{"minCount":"3","status":"on"},"footLinkLeft":{"foot1":"{\\"title\\":\\"\\",\\"url\\":\\"\\",\\"tiaraTag\\":\\"\\"}","foot0":"{\\"title\\":\\"\xec\x97\xb0\xec\x9e\xac\\",\\"url\\":\\"https://news.daum.net/series/\\",\\"tiaraTag\\":\\"series\\"}","foot3":"{\\"title\\":\\"\xed\x8f\xac\xed\x86\xa0\\",\\"url\\":\\"https://news.daum.net/photo/\\",\\"tiaraTag\\":\\"photo\\"}","footer":"{\\"title\\":\\"\xeb\x89\xb4\xec\x8a\xa4\xed\x99\x88\\",\\"url\\":\\"https://news.daum.net/\\"}","foot2":"{\\"title\\":\\"\\",\\"url\\":\\"\\",\\"tiaraTag\\":\\"\\"}","foot4":"{\\"title\\":\\"\xed\x8c\xa9\xed\x8a\xb8\xec\xb2\xb4\xed\x81\xac\\",\\"url\\":\\"https://focus.daum.net/ch/news/factcheck\\",\\"tiaraTag\\":\\"factcheck\\"}","status":"on"},"footLinkRight":{"foot1":"{\\"title\\":\\"\xed\x99\x98\xec\x9c\xa8\\",\\"url\\":\\"https://search.daum.net/search?w=tot&q=\xed\x99\x98\xec\x9c\xa8&DA=TMZ\\",\\"tiaraTag\\":\\"exchange\\"}","foot0":"{\\"title\\":\\"\xec\xa6\x9d\xec\x8b\x9c\\",\\"url\\":\\"https://search.daum.net/search?w=tot&q=\xec\xa ...
# ISO-8859-1
# {'Date': 'Sun, 01 May 2022 08:10:58 GMT', 'Content-Type': 'text/html', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Vary': 'Accept-Encoding, Origin, Accept-Encoding', 'Access-Control-Allow-Origin': '*', 'X-WCSS': 'dC1jb21tb24wMS1id2NhY2hlMjc6MDpjaHR0cDozMA==', 'Cache-Control': 'no-cache, no-store', 'Pragma': 'no-cache', 'Strict-Transport-Security': 'max-age=15724800', 'Content-Encoding': 'gzip'}
# <bound method Response.json of <Response [200]>>
# {}
# True
# 200

# %%
print(response.url)
# Out:
# https://www.daum.net

# %%
print(response.content)
# Out:
# b'<!DOCTYPE html><html lang="ko"> <head> <meta charset="utf-8" /> <title>Daum</title> <meta http-equiv="x-ua-compatible" content="IE=edge" /> <meta property="og:url" content="//www.daum.net/" /> <meta property="og:type" content="website" /> <meta property="og:title" content="Daum" /> <meta http-equiv="Pragma" content="no-cache" /> <meta http-equiv="Expires" content="-1" /> <meta name="referrer" content="origin" /> <meta property="og:image" content="https://i1.daumcdn.net/svc/image/U03/common_icon/5587C4E4012FCD0001" /> <meta property="og:description" content="\xeb\x82\x98\xec\x9d\x98 \xea\xb4\x80\xec\x8b\xac \xec\xbd\x98\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xea\xb0\x80\xec\x9e\xa5 \xec\xa6\x90\xea\xb2\x81\xea\xb2\x8c \xeb\xb3\xbc \xec\x88\x98 \xec\x9e\x88\xeb\x8a\x94 Daum" /> <meta name="msapplication-task" content="name=Daum;action-uri=//www.daum.net/;icon-uri=/favicon.ico" /> <meta name="msapplication-task" content="name=\xeb\xaf\xb8\xeb\x94\x94\xec\x96\xb4\xeb\x8b\xa4\xec\x9d\x8c;action-uri=//news.daum.net/;icon-uri=/media_favicon.ico" /> <meta name="msapplication-task" content="name=\xeb\xa9\x94\xec\x9d\xbc;action-uri=//mail.daum.net;icon-uri=/mail_favicon.ico" /> <link href="https://t1.daumcdn.net/top/favicon.ico" rel="shortcut icon" /> <meta name="referrer" content="origin" /> <link rel="search" type="application/opensearchdescription+xml" href="https://search.daum.net/OpenSearch.xml" title="\xeb\x8b\xa4\xec\x9d\x8c" /> <link rel="stylesheet" href="https://t1.daumcdn.net/top/tiller-pc/h/production/20220420_132344/common.css" /> <script src="https://t1.daumcdn.net/kas/static/na.min.js"></script> <script type="text/javascript"> window.tillerInitData = {"header":{"timestamp":1651392658747},"body":{"tabs":{"media":{"code":"media","name":"\xeb\xaf\xb8\xeb\x94\x94\xec\x96\xb4","renderType":"NONE","position":18,"board":false,"morePage":false,"page":"{\\"tab\\":\\"media\\",\\"page\\":1,\\"last\\":true,\\"token\\":null,\\"ts\\":null}"},"katv":{"code":"katv","name":"\xec\xb9\xb4\xec\xb9\xb4\xec\x98\xa4TV","renderType":"NONE","position":19,"board":false,"morePage":false,"page":"{\\"tab\\":\\"katv\\",\\"page\\":1,\\"last\\":true,\\"token\\":null,\\"ts\\":null}"},"social":{"code":"social","name":"\xec\x86\x8c\xec\x85\x9c","renderType":"NONE","position":20,"board":false,"morePage":false,"page":"{\\"tab\\":\\"social\\",\\"page\\":1,\\"last\\":true,\\"token\\":null,\\"ts\\":null}"},"channel":{"code":"channel","name":"\xec\xb1\x84\xeb\x84\x90","renderType":"NONE","position":21,"board":false,"morePage":false,"page":"{\\"tab\\":\\"channel\\",\\"page\\":1,\\"last\\":true,\\"token\\":null,\\"ts\\":null}"}},"boxes":{"media":[{"code":2372,"type":"PC_MEDIA_NEWS1","items":{"op":{"tab":"news1","title":"\xeb\x89\xb4\xec\x8a\xa4","url":"https://news.daum.net/"},"issue":{"title":"\'\xec\xbd\x94\xeb\xa1\x9c\xeb\x82\x9819\' \xed\x98\x84\xed\x99\xa9","url":"https://news.daum.net/covid19","iconType":"ISSUE2","status":"on"},"breakingNewsOp":{"minCount":"3","status":"on"},"footLinkLeft":{"foot1":"{\\"title\\":\\"\\",\\"url\\":\\"\\",\\"tiaraTag\\":\\"\\"}","foot0":"{\\"title\\":\\"\xec\x97\xb0\xec\x9e\xac\\",\\"url\\":\\"https://news.daum.net/series/\\",\\"tiaraTag\\":\\"series\\"}","foot3":"{\\"title\\":\\"\xed\x8f\xac\xed\x86\xa0\\",\\"url\\":\\"https://news.daum.net/photo/\\",\\"tiaraTag\\":\\"photo\\"}","footer":"{\\"title\\":\\"\xeb\x89\xb4\xec\x8a\xa4\xed\x99\x88\\",\\"url\\":\\"https://news.daum.net/\\"}","foot2":"{\\"title\\":\\"\\",\\"url\\":\\"\\",\\"tiaraTag\\":\\"\\"}","foot4":"{\\"title\\":\\"\xed\x8c\xa9\xed\x8a\xb8\xec\xb2\xb4\xed\x81\xac\\",\\"url\\":\\"https://focus.daum.net/ch/news/factcheck\\",\\"tiaraTag\\":\\"factcheck\\"}","status":"on"},"footLinkRight":{"foot1":"{\\"title\\":\\"\xed\x99\x98\xec\x9c\xa8\\",\\"url\\":\\"https://search.daum.net/search?w=tot&q=\xed\x99\x98\xec\x9c\xa8&DA=TMZ\\",\\"tiaraTag\\":\\"exchange\\"}","foot0":"{\\"title\\":\\"\xec\xa6\x9d\xec\x8b\x9c\\",\\"url\\":\\"https://search.daum.net/search?w=tot&q=\xec\xa ...

# %%
print(response.encoding)
# Out:
# ISO-8859-1

# %%
print(response.headers)
# Out:
# {'Date': 'Sun, 01 May 2022 08:10:58 GMT', 'Content-Type': 'text/html', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Vary': 'Accept-Encoding, Origin, Accept-Encoding', 'Access-Control-Allow-Origin': '*', 'X-WCSS': 'dC1jb21tb24wMS1id2NhY2hlMjc6MDpjaHR0cDozMA==', 'Cache-Control': 'no-cache, no-store', 'Pragma': 'no-cache', 'Strict-Transport-Security': 'max-age=15724800', 'Content-Encoding': 'gzip'}

# %%
print(response.json)
# Out:
# <bound method Response.json of <Response [200]>>

# %%
print(response.links)
# Out:
# {}

# %%
print(response.ok)
# Out:
# True

# %%
print(response.status_code)
# Out:
# 200

# %%
import requests
from bs4 import BeautifulSoup

url="http://www.daum.net/"
response=requests.get(url)
print(response.text[:500])
print(type(response.text))

print(type(BeautifulSoup(response.text,'html.parser')))

soup=BeautifulSoup(response.text, 'html.parser')
print(soup.title)
# Out:
# <class 'str'>
# <class 'bs4.BeautifulSoup'>
# <title>Daum</title>

# %%
import requests
from bs4 import BeautifulSoup

url="http://www.daum.net/"
response=requests.get(url)
#print(response.text[:500])
soup=BeautifulSoup(response.text, 'html.parser')

print(soup.title)
print(soup.title.string)
print(soup.span)
print(soup.findAll('span'))
# Out:
# <title>Daum</title>
# Daum
# None
# []

# %%
from bs4 import BeautifulSoup
import requests

url="http://www.daum.net/"
response=requests.get(url)
soup=BeautifulSoup(response.text, 'html.parser')

#file=open('daum.html','w',encoding='utf-8')
#file.write(response.text)
#file.close()

#print(soup.title)
#print(soup.title.string)
#print(soup.span)
#print(soup.findAll('span'))

#html 문서에서 모든 a태그를 가져오는 코드
result=soup.findAll('a',"link_favorsch")
# Out:
# []

# %% [markdown]
# 예쁘게 출력하기

# %%
from bs4 import BeautifulSoup
import requests
from datetime import datetime

url="http://www.daum.net/"
response=requests.get(url)
soup=BeautifulSoup(response.text, 'html.parser')
rank=1
results=soup.findAll('a','link_favorsch')

print(datetime.today().strftime("%Y년 %m월 %d일의 실시간 검색어 순위입니다.\n"))

for result in results:
      print(rank,"위 :", result.get_text(),"\n")
      rank+=1
# Out:
# 2022년 05월 02일의 실시간 검색어 순위입니다.

# %% [markdown]
# 파일로 출력하기

# %%
from bs4 import BeautifulSoup
import requests
from datetime import datetime

url = "https://datalab.naver.com/keyword/realtimeList.naver?age=20s"
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
rank = 1

results = soup.findAll('a','link_favorsch')

search_rank_file = open("rankresult.txt","a")

print(datetime.today().strftime("%Y년 %m월 %d일의 실시간 검색어 순위입니다.\n"))

for result in results:
    search_rank_file.write(str(rank)+"위:"+result.get_text()+"\n")
    print(rank,"위 : ",result.get_text(),"\n")
    rank += 1

# %% [markdown]
# 응용해보기

# %%
from bs4 import BeautifulSoup
import requests
from datetime import datetime

headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'}
url = "https://datalab.naver.com/keyword/realtimeList.naver?age=20s"
response = requests.get(url,headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')
rank = 1
# span - item_title
results = soup.findAll('span','item_title')

print(response.text)

search_rank_file = open("rankresult.txt","a")

print(datetime.today().strftime("%Y년 %m월 %d일의 실시간 검색어 순위입니다.\n"))

for result in results:
    search_rank_file.write(str(rank)+"위:"+result.get_text()+"\n")
    print(rank,"위 : ",result.get_text(),"\n")
    rank += 1
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#     <meta charset="utf-8">
#     <!-- [D] Internet Explorer Document Mode 최신으로 설정 -->
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <title>페이지를 찾을 수 없습니다. : 빅데이터포털</title>
#     <style type="text/css">
#         /* NHN Technology Services MJH 151228 */
#         /* Common */
#         html, body { height: 100%; }
#         body, p, h1, h2, h3, h4, h5, h6, ul, ol, li, dl, dt, dd, table, th, td, form, fieldset, legend, input, textarea, button, select { margin: 0; padding: 0; }
#         body{ background: #3a3d40; font-family: '나눔고딕',NanumGothic,'돋움',Dotum,Helvetica,sans-serif; font-size: 16px; color: #404d5d; letter-spacing: -1px; }
#         a { color: inherit; text-decoration: none; }
#         .blind { overflow: hidden; position: absolute; clip: rect(0 0 0 0); width: 1px; height: 1px; margin: -1px; }
#         .sp,
#         .sp_before:before { background-image: url(https://ssl.pstatic.net/static.datalab/202203250433/img/sp_error.png); background-repeat: no-repeat; }
#         .wrap { min-width: 1200px; }
#         .container { background: #fff; }
#         .content_error { min-height: 910px; padding-top: 240px; text-align: center; box-sizing: border-box; }
#         .error_title { font-weight: normal; font-size: 33px; }
#         .error_title:before { display:block; width: 40px; height: 40px; margin: 0 auto 26px; background-position: 0 0; content: ''; }
#         .error_title:after { display: block; width: 50px; height: 2px; margin: 25px auto 0; background: #d5dce2; content: ''; }
#         .error_desc { margin-top: 31px; line-height: 30px; }
#         .error_desc .link { color: #4a8fda; text-decoration: underline; }
#         .error_prev { display: inline-block; margin-top: 70px; color: #777; }
#         .error_prev:before { display:inline-block; width: 18px; height: 17px; margin-right: 7px; background-position: -44px 0 ; vertical-align: -3px; content: ''; }
#         .footer { width: 100%; height: 120px; background: #3a3d40; color: #999; }
#         .footer a { color: inherit; }
#         .footer .footer_inner { width: 1090px; margin: 0 auto; padding-top: 40px; text-align: center; }
#         .footer .footer_info { font-size: 12px; }
#         .footer .footer_info strong { color: #ccc; }
#         .footer .footer_info a:hover { text-decoration: underline; }
#         .footer .footer_info a + a:before { display: inline-block; width: 1px; height: 11px; margin: 0 6px; background: #4d4f52; vertical-align: -2px; content: ''; }
#         .footer .footer_copyright { margin-top: 19px; font-family: Verdana; font-size: 9px; letter-spacing: 0; }
#         .footer .footer_copyright strong a:hover { color: #ccc; text-decoration: underline; }
#         .footer .footer_logo { height: 11px; width: 62px; background-position: 0px -44px; display: inline-block; margin-right: 10px; vertical-align: -2px; }
#         .footer .copyright { font-family: Tahoma; font-size: 10px; }
#     </style>
# </head>
#
# <body>
# <div id="wrap" class="wrap">
#
#     <!-- container -->
#     <div id="container" class="container" role="main">
#         <!-- content -->
#         <div id="content" class="content_error">
#             <h1 class="error_title sp_before">오류로 데이터 표시를 할 수 없습니다.</h1>
#             <p class="error_desc">
#                 이용에 불편을 드려서 죄송합니다.
#                 궁금한 사항은 <a href="https://help.naver.com/support/service/main.nhn?serviceNo=14493" target="_blank" class="link">고객센터</a>에 문의해주시면 안내드리겠습니다.<br>
#                 감사합니다.
#             </p>
#             <a href="javascript:history.back()" class="error_prev sp_before">이전 페이지로</a>
#         </div>
#         <!-- //content -->
#     </div>
#     <!-- //container -->
#
#     <!-- footer -->
#     <div id="footer" class="footer">
#         <div class="footer_inner">
#             <div class="footer_info">
#                 <a href="https://policy.naver.com/rules/service.html" target="_blank">이용약관</a>
#                 <a href="https://policy.naver.com/rules/privacy.html" target="_blank"><strong>개인정보취급방침</strong></a>
#                 <a href="https://policy.naver.com/rules/disclaimer.html" target="_blank">책임의 한계와 법적고지</a>
#                 <a href="https://help.naver.com/support/service/main.nhn?serviceNo=14493" target="_blank">고객센터</a>
#             </div>
#             <div class="footer_copyright">
#                 <a href="https://www.naver.com/" target="_blank" class="footer_logo sp"><span class="blind">NAVER</span></a>
#                 <em class="copyright">Copyright ©</em>
#                 <strong><a href="https://www.navercorp.com/ko/index.nhn" target="_blank">NAVER Corp.</a></strong> All Rights Reserved.
#             </div>
#         </div>
#     </div>
#     <!-- //footer -->
#
# </div>
#
# </body>
# </html>
#
# 2022년 05월 02일의 실시간 검색어 순위입니다.
